# %%
import pandas as pd
import string, re

# %%
df = pd.read_csv('./data/highest-grossing-1000-movies.csv')
df
# Out:
#      Unnamed: 0                                              Title  \
# 0             0  Star Wars: Episode VII - The Force Awakens (2015)
# 1             1                           Avengers: Endgame (2019)
# 2             2                                      Avatar (2009)
# 3             3                               Black Panther (2018)
# 4             4                      Avengers: Infinity War (2018)
# ..          ...                                                ...
# 913         913                                The Notebook (2004)
# 914         914                   Jimmy Neutron: Boy Genius (2001)
# 915         915                               Eat Pray Love (2010)
# 916         916                 The Texas Chainsaw Massacre (2003)
# 917         917                                   Zookeeper (2011)
#
#                                             Movie Info  \
# 0    As a new threat to the galaxy rises, Rey, a de...
# ...

# %%
movies = pd.read_json('./data/final_movies_combined.json')
movies[movies['Title'] == 'Magnum Force']
movies.iloc[386]
# Out:
# Rank                                                           7
# Title                                        Last Tango in Paris
# Studio                                            United Artists
# Gross                                                   16711000
# Year                                                        1973
# Words          {'know': 40, 'yes': 35, 'go': 26, 'like': 26, ...
# Word Counts                                                  335
# Name: 386, dtype: object

# %%
suicides = pd.read_csv('./data/who_suicide_stats.csv')
suicides
# Out:
#                                country  total  population  perCapita  \
# 0                            Argentina   2987    38859125      7.687
# 1                              Armenia     67     2810664      2.384
# 2                                Aruba      2       97110      2.060
# 3                            Australia   2608    21600180     12.074
# 4                              Austria   1291     8079615     15.978
# ..                                 ...    ...         ...        ...
# 85                      United Kingdom   4824    60091793      8.028
# 86            United States of America  41143   295322862     13.932
# 87                             Uruguay    546     3164670     17.253
# 88                          Uzbekistan   1950    26838924      7.266
# 89  Venezuela (Bolivarian Republic of)    618    27345912      2.260
#
#        continent
# 0   southAmerica
# 1         europe
# 2   northAmerica
# 3        oceania
# 4         europe
# ..           ...
# ...
